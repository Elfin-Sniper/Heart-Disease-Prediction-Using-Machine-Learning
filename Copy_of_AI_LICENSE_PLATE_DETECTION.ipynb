# %% [markdown]
# <a href="https://colab.research.google.com/github/Elfin-Sniper/Heart-Disease-Prediction-Using-Machine-Learning/blob/main/Copy_of_AI_LICENSE_PLATE_DETECTION.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install torch torchvision ultralytics opencv-python numpy pytesseract
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 59.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 52.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 39.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.7 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 36.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 993.8/993.8 kB 49.0 MB/s eta 0:00:00
# ...
#   Attempting uninstall: nvidia-nvjitlink-cu12
# ...

# %%
! git clone https://github.com/ultralytics/yolov5
# Out:
# Cloning into 'yolov5'...
# remote: Enumerating objects: 17360, done.
# remote: Counting objects: 100% (52/52), done.
# remote: Compressing objects: 100% (34/34), done.
# remote: Total 17360 (delta 36), reused 18 (delta 18), pack-reused 17308 (from 2)
# Receiving objects: 100% (17360/17360), 16.24 MiB | 28.48 MiB/s, done.
# Resolving deltas: 100% (11904/11904), done.

# %%
cd yolov5
# Out:
# /content/yolov5

# %%
# !pip install -r requirements.txt

# %%
import torch
print(torch.cuda.is_available())  # Should return True if GPU is available
# Out:
# True

# %%
import cv2

cap = cv2.VideoCapture("/content/yolov5/videoplayback.mp4")  # Or use webcam: cap = cv2.VideoCapture(0)
count = 0

while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    cv2.imwrite(f"dataset/images/frame_{count}.jpg", frame)
    count += 1

cap.release()

# %%
# !pip install labelImg
labelImg
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 247.7/247.7 kB 4.1 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 8.2/8.2 MB 80.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.1/61.1 MB 13.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 276.4/276.4 kB 22.9 MB/s eta 0:00:00
# ...
#   Created wheel for labelImg: filename=labelImg-1.8.6-py2.py3-none-any.whl size=261521 sha256=8f41e366130eb911333ba6ad9a30b99843f16938bfd418f57401a69fcec8708f
#   Stored in directory: /root/.cache/pip/wheels/79/90/db/e0700438d3647c0209061d77992c901d3c786a56fec574ac86
# Successfully built labelImg
# ...
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-10-b01b0c601a77> in <cell line: 0>()
#       1 get_ipython().system('pip install labelImg')
# ----> 2 labelImg
#
# NameError: name 'labelImg' is not defined

# %%
# !pip install labelImg
# !labelImg
# Out:
# ...
# QObject::moveToThread: Current thread (0x2b65380) is not the object's thread (0x2dcc7b0).
# Cannot move to target thread (0x2b65380)
#
# qt.qpa.plugin: Could not load the Qt platform plugin "xcb" in "/usr/local/lib/python3.11/dist-packages/cv2/qt/plugins" even though it was found.
# This application failed to start because no Qt platform plugin could be initialized. Reinstalling the application may fix this problem.
#
# Available platform plugins are: xcb, eglfs, linuxfb, minimal, minimalegl, offscreen, vnc, wayland-egl, wayland, wayland-xcomposite-egl, wayland-xcomposite-glx, webgl.

# %%
import kagglehub

# Download latest version
path = kagglehub.dataset_download("fareselmenshawii/large-license-plate-dataset")

print("Path to dataset files:", path)
# Out:
# Resuming download from 425721856 bytes (2096206066 bytes left)...
# Resuming download from https://www.kaggle.com/api/v1/datasets/download/fareselmenshawii/large-license-plate-dataset?dataset_version_number=1 (425721856/2521927922) bytes left.
# 100%|██████████| 2.35G/2.35G [00:25<00:00, 83.0MB/s]
# Extracting files...
# Path to dataset files: /root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1

# %%
print(path)
# Out:
# /root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1

# %%
data_yaml = """train: /root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1/images/train
val: /root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1/images/val
nc: 2
names: ["vehicle", "license_plate"]
"""

with open("data.yaml", "w") as f:
    f.write(data_yaml)

# %%
# !cat data.yaml
# Out:
# train: /root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1/images/train
# val: /root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1/images/val
# nc: 2
# names: ["vehicle", "license_plate"]

# %%
train = "/root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1/images/train"
val = "/root/.cache/kagglehub/datasets/fareselmenshawii/large-license-plate-dataset/versions/1/images/val"
nc = 2
names = ["vehicle", "license_plate"]

# %%
# !python train.py --img 640 --batch 16 --epochs 3 --data data.yaml --weights yolov5s.pt
# Out:
# Streaming output truncated to the last 5000 lines.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.98G    0.03658   0.008188   0.000531         30        640:  45% 717/1592 [05:08<07:23,  1.97it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.98G    0.03657   0.008188   0.000531         28        640:  45% 718/1592 [05:09<07:26,  1.96it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
#   with torch.cuda.amp.autocast(amp):
#         1/2      4.98G    0.03658   0.008187  0.0005311         24        640:  45% 719/1592 [05:09<06:11,  2.35it/s]/content/yolov5/train.py:412: FutureWarning: `torch.cuda.amp.autocast(args...)` is deprecated. Please use `torch.amp.autocast('cuda', args...)` instead.
# ...

# %%
# !pip install ultralytics

# %%
from ultralytics import YOLO

# Load the trained YOLO model
self.vehicle_model = YOLO("runs/train/exp/weights/best.pt")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-23-557d8019c109> in <cell line: 0>()
#       2
#       3 # Load the trained YOLO model
# ----> 4 self.vehicle_model = YOLO("runs/train/exp/weights/best.pt")
#
# NameError: name 'self' is not defined

# %%
from ultralytics import YOLO

# Load the trained YOLO model
vehicle_model = YOLO("runs/train/exp/weights/best.pt") # Removed 'self.'

# %%
# !ls -R runs/train/
# Out:
# runs/train/:
# exp
#
# runs/train/exp:
# confusion_matrix.png				    PR_curve.png	   val_batch0_pred.jpg
# events.out.tfevents.1743961972.fac886817ac0.3313.0  R_curve.png		   val_batch1_labels.jpg
# F1_curve.png					    results.csv		   val_batch1_pred.jpg
# hyp.yaml					    results.png		   val_batch2_labels.jpg
# labels_correlogram.jpg				    train_batch0.jpg	   val_batch2_pred.jpg
# labels.jpg					    train_batch1.jpg	   weights
# opt.yaml					    train_batch2.jpg
# P_curve.png					    val_batch0_labels.jpg
#
# runs/train/exp/weights:
# best.pt  last.pt

# %%
vehicle_model = YOLO("runs/train/exp/weights/best.pt")

# %%
import cv2
from ultralytics import YOLO

# Load the trained YOLO model
model = YOLO("runs/train/exp/weights/best.pt")

# Class names
CLASS_NAMES = ["vehicle", "license_plate"]

# Load the video
video_path = "/content/videoplayback.mp4"
cap = cv2.VideoCapture(video_path)

# Get video details
width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
fps = cap.get(cv2.CAP_PROP_FPS)

# Define the codec and create VideoWriter object
output_path = "output_detected_video.mp4"
fourcc = cv2.VideoWriter_fourcc(*'mp4v')
out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))

# Run inference frame-by-frame
while cap.isOpened():
    ret, frame = cap.read()
    if not ret:
        break

    # Inference using .predict() to avoid fuse() error
    results = model.predict(source=frame, verbose=False)[0]

    # Draw boxes and labels
    for box in results.boxes:
        x1, y1, x2, y2 = map(int, box.xyxy[0])
        cls_id = int(box.cls[0])
        conf = float(box.conf[0])
        label = f"{CLASS_NAMES[cls_id]} {conf:.2f}"

        color = (0, 255, 0) if cls_id == 0 else (0, 0, 255)
        cv2.rectangle(frame, (x1, y1), (x2, y2), color, 2)
        cv2.putText(frame, label, (x1, y1 - 10), cv2.FONT_HERSHEY_SIMPLEX, 0.6, color, 2)

    out.write(frame)

cap.release()
out.release()
cv2.destroyAllWindows()

print(f"Video saved at: {output_path}")
# Out:
# Video saved at: output_detected_video.mp4

# %%
 from IPython.display import HTML
from base64 import b64encode

mp4 = open(output_path,'rb').read()
data_url = "data:video/mp4;base64," + b64encode(mp4).decode()
HTML(f"""<video width=700 controls><source src="{data_url}" type="video/mp4"></video>""")
